# %% [markdown]
# # Competition Objective is to detect fraud in transactions;
#
# ## Data
#
#
# In this competition you are predicting the probability that an online transaction is fraudulent, as denoted by the binary target ```isFraud```.
#
# The data is broken into two files **identity** and **transaction**, which are joined by ```TransactionID```.
#
# > Note: Not all transactions have corresponding identity information.
#
# **Transaction variables**
#
# - TransactionDT: timedelta from a given reference datetime (not an actual timestamp)
# - TransactionAMT: transaction payment amount in USD
# - ProductCD: product code, the product for each transaction
# - card1 - card6: payment card information, such as card type, card category, issue bank, country, etc.
# - addr: address
# - dist: distance
# - P_ and (R__) emaildomain: purchaser and recipient email domain
# - C1-C14: counting, such as how many addresses are found to be associated with the payment card, etc. The actual meaning is masked.
# - D1-D15: timedelta, such as days between previous transaction, etc.
# - M1-M9: match, such as names on card and address, etc.
# - Vxxx: Vesta engineered rich features, including ranking, counting, and other entity relations.
#
# **Categorical Features - Transaction**
#
# - ProductCD
# - emaildomain
# - card1 - card6
# - addr1, addr2
# - P_emaildomain
# - R_emaildomain
# - M1 - M9
#
# **Categorical Features - Identity**
#
# - DeviceType
# - DeviceInfo
# - id_12 - id_38
#
# **The TransactionDT feature is a timedelta from a given reference datetime (not an actual timestamp).**

# %% [markdown]
# # 1. Importation and memory reduction
# ## 1.1. Importing necessary libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import datetime


# Standard plotly imports
#import plotly.plotly as py
import plotly.graph_objs as go
import ipywidgets
import plotly.express as px
import plotly.tools as tls
from plotly.subplots import make_subplots

from plotly.offline import iplot, init_notebook_mode
#import cufflinks
#import cufflinks as cf
import plotly.figure_factory as ff


# Using plotly + cufflinks in offline mode
init_notebook_mode(connected=True)
#cufflinks.go_offline(connected=True)

# Preprocessing, modelling and evaluating
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, roc_auc_score
from sklearn.model_selection import StratifiedKFold, cross_val_score, KFold, GridSearchCV
from xgboost import XGBClassifier
import xgboost as xgb
import catboost as cb

## Hyperopt modules
from functools import partial

import os
import gc
import time
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## 1.2. Importing train datasets

# %%
gc.collect()
df_train = pd.read_pickle("df_train_v2.pkl")
df_test = pd.read_pickle("df_test_v2.pkl")
sample_submission = pd.read_csv('sample_submission.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     165                 warnings.simplefilter("ignore", Warning)
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:  # noqa: E722
#
# D:\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# D:\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_train_v2.pkl'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     172                 return read_wrapper(
# --> 173                     lambda f: pc.load(f, encoding=encoding, compat=False))
#     174             # compat pickle
#
# D:\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# D:\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_train_v2.pkl'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_pickle(path, compression)
#     178     try:
# --> 179         return try_read(path)
#     180     except Exception:  # noqa: E722
#
# D:\Anaconda3\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     176                 return read_wrapper(
# --> 177                     lambda f: pc.load(f, encoding=encoding, compat=True))
#     178     try:
#
# D:\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# D:\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_train_v2.pkl'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     165                 warnings.simplefilter("ignore", Warning)
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:  # noqa: E722
#
# D:\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# D:\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_train_v2.pkl'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     172                 return read_wrapper(
# --> 173                     lambda f: pc.load(f, encoding=encoding, compat=False))
#     174             # compat pickle
#
# D:\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# D:\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_train_v2.pkl'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-5be80a47a989> in <module>
#       1 gc.collect()
# ----> 2 df_train = pd.read_pickle("df_train_v2.pkl")
#       3 df_test = pd.read_pickle("df_test_v2.pkl")
#       4 sample_submission = pd.read_csv('sample_submission.csv')
#
# D:\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_pickle(path, compression)
#     180     except Exception:  # noqa: E722
#     181         if PY3:
# --> 182             return try_read(path, encoding='latin1')
#     183         raise
#     184
#
# D:\Anaconda3\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     175             except Exception:  # noqa: E722
#     176                 return read_wrapper(
# --> 177                     lambda f: pc.load(f, encoding=encoding, compat=True))
#     178     try:
#     179         return try_read(path)
#
# D:\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#     144         f, fh = _get_handle(path, 'rb',
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#     148             return func(f)
#
# D:\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     428         else:
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#     432
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_train_v2.pkl'

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (590540, 430)
# (506691, 429)

# %% [markdown]
# ## 1.3. Memory reduction

# %%
def resumetable(df):
    n = df.shape[0]
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values  
    summary['Missing %'] = round(summary['Missing'] / n * 100,2)
    summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.loc[0].values
    summary['Second Value'] = df.loc[1].values
    summary['Third Value'] = df.loc[2].values


    return summary

# %% [markdown]
# To see the output of the Resume Table, click to see the output

# %% [markdown]
# # 2. Preprocessing

# %%
df_train.head()
# Out:
#    TransactionID  isFraud  TransactionDT  ...  _Weekdays _Hours _Days
# 0        2987000        0          86400  ...          5      0     2
# 1        2987001        0          86401  ...          5      0     2
# 2        2987002        0          86469  ...          5      0     2
# 3        2987003        0          86499  ...          5      0     2
# 4        2987004        0          86506  ...          5      0     2
#
# [5 rows x 430 columns]

# %%
categorical_features = []
for col in df_train.columns.drop('isFraud') :
    if (df_train[col].dtype == 'object' 
        or df_test[col].dtype=='object' 
        or df_train[col].dtype == 'bool') :
        categorical_features.append(col)
categorical_features.extend(['_merge', '_Weekdays',	'_Hours',	'_Days'])

# %%
categorical_resume = resumetable(df_train[categorical_features])
categorical_resume
# Out:
# Dataset Shape: (590540, 42)
#              Name    dtypes  ...    Second Value     Third Value
# 0       ProductCD    object  ...               W               W
# 1           card1    object  ...            2755            4663
# 2           card2    object  ...             404             490
# 3           card3    object  ...             150             150
# 4           card4    object  ...      mastercard            visa
# 5           card5    object  ...             102             166
# 6           card6    object  ...          credit           debit
# 7           addr1    object  ...             325             330
# 8           addr2    object  ...              87              87
# 9   P_emaildomain    object  ...       gmail.com     outlook.com
# 10  R_emaildomain    object  ...         Maybe_P         Maybe_P
# 11             M1    object  ...            Miss               T
# 12             M2    object  ...            Miss               T
# 13             M3    object  ...            Miss               T
# 14             M4    object  ...              M0              M0
# 15             M5    object  ...               T               F
# 16             M6    object  ...               T               F
# 17             M7    object  ...            Miss               F
# 18             M8    object  ...            Miss               F
# 19             M9    object  ...            Miss               F
# 20          id_12    object  ...        NotFound        NotFound
# 21          id_15    object  ...             New           Found
# 22          id_16    object  ...        NotFound           Found
# 23          id_27    object  ...            Miss            Miss
# 24          id_28    object  ...             New           Found
# 25          id_29    object  ...        NotFound           Found
# 26          id_30    object  ...             iOS            Miss
# 27          id_31    object  ...          Safari          Chrome
# 28          id_33    object  ...        1334x750       1920x1080
# 29          id_34    object  ...  match_status:1  match_status:2
# 30          id_35    object  ...               T               F
# 31          id_36    object  ...               F               F
# 32          id_37    object  ...               F               T
# 33          id_38    object  ...               T               T
# 34     DeviceType    object  ...          mobile         desktop
# 35     DeviceInfo    object  ...      iOS Device         Windows
# 36       dist1_na      bool  ...            True           False
# 37       dist2_na      bool  ...            True            True
# 38         _merge  category  ...            both            both
# 39      _Weekdays      int8  ...               5               5
# 40         _Hours      int8  ...               0               0
# 41          _Days      int8  ...               2               2
#
# [42 rows x 8 columns]

# %%
# Label Encoding
categorical_features_v2 = categorical_features.copy()
for f in categorical_features:
    if float(categorical_resume.loc[categorical_resume['Name']==f, 'Uniques']) > 8 :
        categorical_features_v2.remove(f)
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(df_train[f].values) + list(df_test[f].values))
        df_train[f] = lbl.transform(list(df_train[f].values))
        df_test[f] = lbl.transform(list(df_test[f].values))

# %%
categorical_resume_v2 = resumetable(df_train[categorical_features_v2])
categorical_resume_v2
# Out:
# Dataset Shape: (590540, 30)
#           Name    dtypes  ...    Second Value     Third Value
# 0    ProductCD    object  ...               W               W
# 1        card4    object  ...      mastercard            visa
# 2        card6    object  ...          credit           debit
# 3           M1    object  ...            Miss               T
# 4           M2    object  ...            Miss               T
# 5           M3    object  ...            Miss               T
# 6           M4    object  ...              M0              M0
# 7           M5    object  ...               T               F
# 8           M6    object  ...               T               F
# 9           M7    object  ...            Miss               F
# 10          M8    object  ...            Miss               F
# 11          M9    object  ...            Miss               F
# 12       id_12    object  ...        NotFound        NotFound
# 13       id_15    object  ...             New           Found
# 14       id_16    object  ...        NotFound           Found
# 15       id_27    object  ...            Miss            Miss
# 16       id_28    object  ...             New           Found
# 17       id_29    object  ...        NotFound           Found
# 18       id_30    object  ...             iOS            Miss
# 19       id_34    object  ...  match_status:1  match_status:2
# 20       id_35    object  ...               T               F
# 21       id_36    object  ...               F               F
# 22       id_37    object  ...               F               T
# 23       id_38    object  ...               T               T
# 24  DeviceType    object  ...          mobile         desktop
# 25  DeviceInfo    object  ...      iOS Device         Windows
# 26    dist1_na      bool  ...            True           False
# 27    dist2_na      bool  ...            True            True
# 28      _merge  category  ...            both            both
# 29   _Weekdays      int8  ...               5               5
#
# [30 rows x 8 columns]

# %%
Y_train = df_train['isFraud']
df_train.drop('isFraud', axis = 1, inplace = True)

# %%
categorical_index = [df_train.columns.get_loc(key) for key in categorical_features_v2]

# %% [markdown]
# # 3. Modeling

# %%
train = cb.Pool(df_train, Y_train, cat_features=categorical_index)
test = cb.Pool(df_test, cat_features=categorical_index)
del df_train, Y_train, df_test
gc.collect()
# Out:
# 65

# %%
params = {'depth': [15],
          'learning_rate' : [0.03],
         'l2_leaf_reg': [3],
         'iterations': [1000]}

cb_model = cb.CatBoostClassifier(eval_metric="AUC", 
                                 one_hot_max_size= 8, 
                                 task_type="GPU",
                                 devices='0:1',
                                 verbose = 200,
                                 depth = 15,
                                 l2_leaf_reg = 3,
                                 iterations = 1000)
cb_model.fit(train)
# Out:
# 0:	learn: 0.8108965	total: 1.21s	remaining: 20m 10s
# 200:	learn: 0.9665239	total: 3m 50s	remaining: 15m 15s
# 400:	learn: 0.9848535	total: 7m 36s	remaining: 11m 22s
# 600:	learn: 0.9914796	total: 11m 17s	remaining: 7m 29s
# 800:	learn: 0.9953011	total: 14m 57s	remaining: 3m 43s
# 999:	learn: 0.9973242	total: 18m 37s	remaining: 0us

# %%
cb_model.get_all_params()
# Out:
# {'add_ridge_penalty_to_loss_function': False,
#  'bagging_temperature': 1,
#  'bayesian_matrix_reg': 0.10000000149011612,
#  'best_model_min_trees': 1,
#  'boost_from_average': False,
#  'boosting_type': 'Plain',
#  'bootstrap_type': 'Bayesian',
#  'border_count': 128,
#  'class_names': [0, 1],
#  'classes_count': 0,
#  'combinations_ctr': ['Borders:CtrBorderCount=15:CtrBorderType=Uniform:TargetBorderCount=1:TargetBorderType=MinEntropy:Prior=0/1:Prior=0.5/1:Prior=1/1',
#   'FeatureFreq:CtrBorderCount=15:CtrBorderType=Median:Prior=0/1'],
#  'counter_calc_method': 'SkipTest',
#  'ctr_history_unit': 'Sample',
#  'ctr_target_border_count': 1,
#  'data_partition': 'FeatureParallel',
#  'depth': 15,
#  'devices': '0:1',
#  'eval_metric': 'AUC',
#  'feature_border_type': 'GreedyLogSum',
#  'fold_permutation_block': 64,
#  'fold_size_loss_normalization': False,
#  'gpu_cat_features_storage': 'GpuRam',
#  'gpu_ram_part': 0.95,
#  'grow_policy': 'SymmetricTree',
#  'has_time': False,
#  'iterations': 1000,
#  'l2_leaf_reg': 3,
#  'leaf_estimation_backtracking': 'AnyImprovement',
#  'leaf_estimation_iterations': 10,
#  'leaf_estimation_method': 'Newton',
#  'learning_rate': 0.029999999329447743,
#  'loss_function': 'Logloss',
#  'max_ctr_complexity': 4,
#  'max_leaves': 32768,
#  'min_data_in_leaf': 1,
#  'min_fold_size': 100,
#  'nan_mode': 'Min',
#  'observations_to_bootstrap': 'TestOnly',
#  'one_hot_max_size': 8,
#  'permutation_count': 1,
#  'pinned_memory_bytes': '104857600',
#  'random_seed': 0,
#  'random_strength': 1,
#  'rsm': 1,
#  'score_function': 'Cosine',
#  'simple_ctr': ['Borders:CtrBorderCount=15:CtrBorderType=Uniform:TargetBorderCount=1:TargetBorderType=MinEntropy:Prior=0/1:Prior=0.5/1:Prior=1/1',
#   'FeatureFreq:CtrBorderCount=15:CtrBorderType=MinEntropy:Prior=0/1'],
#  'task_type': 'GPU',
#  'use_best_model': False}

# %%
sample_submission['isFraud'] = cb_model.predict_proba(test)[:,1]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cb_model.save_model('/content/gdrive/My Drive/model_cat')

# %%
sample_submission.to_csv('/content/gdrive/My Drive/submission.csv', index=False)

# %%
grid_search_result = cb_model.grid_search(params,
                                          cv = 5,
                                          X=train,
                                          stratified = True,
                                          plot=True)
